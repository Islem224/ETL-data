# %% [markdown]
# <h1 align="center" style="color:red;">Nettoyage des Réservations</h1>

# %% [markdown]
# <h1> Analyses et chargement de données</h1>

# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\user\Desktop\stage\BI\bd-reservation.csv')

# %%
df.head()
# Out:
#     Type  Operator                   Hotel Name Region  \
# 0  Cancel     MEMI     RIADH PALMS RESORT & SPA    MLD
# 1  Normal     MEMI    MEDINA SOLARIA & THALASSO    MLD
# 2  Normal      ETX   HOUDA YASMINE MARINA & SPA    MLD
# 3  Normal      JUM  HOUDA GOLF BEACH & AQUAPARK    MLD
# 4  Normal    JUPLX     EL MOURADI CLUB KANTAOUI    MLD
#
#                     Operator Name   Voucher    #  Hotel   \
# 0  CHRISTIAN TOUR | MEMENTO GROUP   1055386  1.0  RPALMS
# 1  CHRISTIAN TOUR | MEMENTO GROUP   1057010  1.0    MEDS
# 2                  EMERALD TRAVEL  EE195324  1.0      HY
# 3                JOIN UP! MOLDOVA  11750030  1.0      HG
# 4                 JOIN UP! POLSKA    116701  1.0   EMCEK
#
#                                           Hotel Note Check In Date  ...  \
# 0                                              GRS24    2021-08-14  ...
# 1                                       SPO BW 07.07    2021-07-19  ...
# ...

# %%
df.shape
# Out:
# (25980, 49)

# %%
#Vérifiez les types de données de chaque colonne.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25980 entries, 0 to 25979
# Data columns (total 49 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Type                             25973 non-null  object
#  1   Operator                         25971 non-null  object
#  2   Hotel Name                       25971 non-null  object
#  3   Region                           25971 non-null  object
#  4   Operator Name                    25971 non-null  object
#  5   Voucher                          25971 non-null  object
#  6   #                                25971 non-null  float64
#  7   Hotel                            25971 non-null  object
#  8   Hotel Note                       20655 non-null  object
#  9   Check In Date                    25971 non-null  object
#  10  Check Out                        25971 non-null  object
#  11  Day                              25971 non-null  float64
# ...

# %%
df.describe()
# Out:
#                   #           Day         Adult  Extra Bed         Child  \
# count  25971.000000  25971.000000  25971.000000    25971.0  25971.000000
# mean       1.114936      6.880829      2.111509        0.0      0.363906
# std        0.431522      1.746289      0.740933        0.0      0.609567
# min        1.000000      0.000000      0.000000        0.0      0.000000
# 25%        1.000000      7.000000      2.000000        0.0      0.000000
# 50%        1.000000      7.000000      2.000000        0.0      0.000000
# 75%        1.000000      7.000000      2.000000        0.0      1.000000
# max       10.000000     23.000000     17.000000        0.0      3.000000
#
#              Infant    Room Count  Buying Calculation Information  \
# count  25971.000000  25971.000000                             0.0
# mean       0.018790      1.067845                             NaN
# std        0.136634      0.608579                             NaN
# ...

# %%
#verification des valeurs manquante
df.isnull().sum()
# Out:
# Type                                   7
# Operator                               9
# Hotel Name                             9
# Region                                 9
# Operator Name                          9
# Voucher                                9
# #                                      9
# Hotel                                  9
# Hotel Note                          5325
# Check In Date                          9
# Check Out                              9
# Day                                    9
# Room                                   9
# Room Definition                        9
# Room Type                              9
# Room Type.1                            9
# Board                                  9
# All. T                                 9
# Hotel Conf.                            9
# Conf. Date                          7117
# Opr.Conf.Date                       7283
# Origin                                 9
# Bubble                                 9
# ...

# %%
#supprimer les valeurs manquantes
df.notnull()
# Out:
#        Type   Operator  Hotel Name  Region  Operator Name  Voucher     #  \
# 0       True      True        True    True           True     True  True
# 1       True      True        True    True           True     True  True
# 2       True      True        True    True           True     True  True
# 3       True      True        True    True           True     True  True
# 4       True      True        True    True           True     True  True
# ...      ...       ...         ...     ...            ...      ...   ...
# 25975   True      True        True    True           True     True  True
# 25976   True      True        True    True           True     True  True
# 25977   True      True        True    True           True     True  True
# 25978   True      True        True    True           True     True  True
# 25979   True      True        True    True           True     True  True
#
#        Hotel   Hotel Note  Check In Date  ...  Special Code  \
# ...

# %%
df.notnull().sum()
# Out:
# Type                               25973
# Operator                           25971
# Hotel Name                         25971
# Region                             25971
# Operator Name                      25971
# Voucher                            25971
# #                                  25971
# Hotel                              25971
# Hotel Note                         20655
# Check In Date                      25971
# Check Out                          25971
# Day                                25971
# Room                               25971
# Room Definition                    25971
# Room Type                          25971
# Room Type.1                        25971
# Board                              25971
# All. T                             25971
# Hotel Conf.                        25971
# Conf. Date                         18863
# Opr.Conf.Date                      18697
# Origin                             25971
# Bubble                             25971
# ...

# %% [markdown]
# <h1> traitement des valeurs manquantes</h1>

# %% [markdown]
# <h3> Supprimer les colonnes totalement vides </h3>

# %%
# Liste des colonnes à supprimer
cols_to_drop = [
    "Buying Calculation Information", "Selling Calculation Information",
    "Manager", "Dispaly Operator", "Hotel Manager", "Print Date"
]

# Suppression des colonnes
df.drop(columns=cols_to_drop, inplace=True)
df.head()
# Out:
#      Type Operator                   Hotel Name Region  \
# 0  Cancel     MEMI     RIADH PALMS RESORT & SPA    MLD
# 1  Normal     MEMI    MEDINA SOLARIA & THALASSO    MLD
# 2  Normal      ETX   HOUDA YASMINE MARINA & SPA    MLD
# 3  Normal      JUM  HOUDA GOLF BEACH & AQUAPARK    MLD
# 4  Normal    JUPLX     EL MOURADI CLUB KANTAOUI    MLD
#
#                     Operator Name   Voucher    #   Hotel  \
# 0  CHRISTIAN TOUR | MEMENTO GROUP   1055386  1.0  RPALMS
# 1  CHRISTIAN TOUR | MEMENTO GROUP   1057010  1.0    MEDS
# 2                  EMERALD TRAVEL  EE195324  1.0      HY
# 3                JOIN UP! MOLDOVA  11750030  1.0      HG
# 4                 JOIN UP! POLSKA    116701  1.0   EMCEK
#
#                                           Hotel Note Check In Date  ...  \
# 0                                              GRS24    2021-08-14  ...
# 1                                       SPO BW 07.07    2021-07-19  ...
# ...

# %% [markdown]
# <h3>Convertir les colonnes de dates au format datetime</h3>
